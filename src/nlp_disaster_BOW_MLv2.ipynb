# %% [markdown]
# ### __Natural Language Processing: Machine Learning Models__
# > - https://www.kaggle.com/code/philculliton/nlp-getting-started-tutorial/notebook

# %%
# import libraries
import numpy as np
import pandas as pd
from datetime import datetime, timezone, timedelta
import datetime as dt
import time
import random
from collections import Counter
from PIL import Image
import random
import string
from joblib import Parallel, delayed
import math

import warnings
warnings.filterwarnings('ignore')

# import regex
import re

# import nltk
import nltk 
from nltk.corpus import stopwords
from nltk.corpus import wordnet as wn
from nltk import sent_tokenize
from nltk.tokenize import word_tokenize
from nltk.stem.porter import PorterStemmer
from nltk.stem import WordNetLemmatizer

# import matplotlib
from matplotlib import pyplot
import matplotlib.pyplot as plt
from matplotlib.pyplot import figure
import matplotlib.image as mpimg
#plt.imshow(mpimg.imread('jan_aug_tempanom.png'))

# import seaborn
import seaborn as sns

# import scipy.cluster.hierarchy
import scipy
import scipy.linalg as la
import scipy.cluster.hierarchy as sch
from scipy.cluster.vq import whiten, kmeans, vq
from scipy.stats import multivariate_normal
from pathlib import Path

# import sklearn
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler
from sklearn.preprocessing import Normalizer
import sklearn.model_selection as model_selection
import sklearn.model_selection as cross_validation
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV
from sklearn.model_selection import train_test_split
from sklearn.model_selection import KFold
import sklearn.metrics as metrics
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import r2_score
from sklearn.metrics import accuracy_score
from sklearn.metrics import f1_score
from sklearn.metrics import precision_score
from sklearn.metrics import recall_score
from sklearn.metrics import log_loss
from sklearn.metrics import roc_auc_score
from sklearn.metrics import roc_curve
from sklearn.metrics import plot_roc_curve
from sklearn.metrics import average_precision_score, f1_score, classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import plot_precision_recall_curve, plot_confusion_matrix
from sklearn.feature_selection import RFE
from sklearn import linear_model, datasets
from sklearn.linear_model import LinearRegression, Ridge
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import svm
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.tree import export_graphviz
#from sklearn.externals.six import StringIO  
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

from sklearn.naive_bayes import BernoulliNB # Bernoulli because we have binary features
from sklearn.pipeline import Pipeline

# For converting words into frequency counts
from sklearn import feature_extraction, linear_model, model_selection, preprocessing
from sklearn.feature_extraction.text import CountVectorizer
from sklearn.feature_extraction.text import TfidfVectorizer

import statsmodels.api as sm
from statsmodels.tsa.stattools import adfuller
from statsmodels.tsa.seasonal import seasonal_decompose
from statsmodels.tsa.arima_model import ARIMA
from pandas.plotting import register_matplotlib_converters
register_matplotlib_converters()

# Importing the Keras libraries and packages
from keras.models import Sequential
from keras.layers import Dense
from keras.layers import LSTM
from keras.layers import Dropout

from sklearn.preprocessing import MinMaxScaler

#for showing 2D plot
# %matplotlib inline    

# to be able to see multiple ouputs from sungle cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %% [markdown]
# #### __Import Data__

# %%
# import train data
test_df = pd.read_csv('/content/preprocessed2nd_test_data.csv')
test_df.info()
test_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3263 entries, 0 to 3262
# Data columns (total 6 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     3263 non-null   int64
#  1   keyword                3263 non-null   object
#  2   location               3263 non-null   object
#  3   text                   3263 non-null   object
#  4   text_preprocessed      3263 non-null   object
#  5   text_preprocessed_2nd  3263 non-null   object
# dtypes: int64(1), object(5)
# memory usage: 153.1+ KB
#          id keyword location  \
# 0         0    None     None
# 1         2    None     None
# 2         3    None     None
# 3         9    None     None
# 4        11    None     None
# ...     ...     ...      ...
# 3258  10861    None     None
# 3259  10865    None     None
# 3260  10868    None     None
# 3261  10874    None     None
# 3262  10875    None     None
#
#                                                    text  \
# 0                    Just happened a terrible car crash
# 1     Heard about #earthquake is different cities, s...
# 2     there is a forest fire at spot pond, geese are...
# 3              Apocalypse lighting. #Spokane #wildfires
# 4         Typhoon Soudelor kills 28 in China and Taiwan
# ...                                                 ...
# 3258  EARTHQUAKE SAFETY LOS ANGELES ÛÒ SAFETY FASTE...
# 3259  Storm in RI worse than last hurricane. My city...
# 3260  Green Line derailment in Chicago http://t.co/U...
# 3261  MEG issues Hazardous Weather Outlook (HWO) htt...
# 3262  #CityofCalgary has activated its Municipal Eme...
#
#                                       text_preprocessed  \
# 0                           happened terrible car crash
# 1     heard earthquake different city stay safe ever...
# 2     forest fire spot pond goose fleeing across str...
# 3                  apocalypse lighting spokane wildfire
# 4                    typhoon soudelor kill china taiwan
# ...                                                 ...
# 3258  earthquake safety los angeles safety fastener ...
# 3259  storm ri worse last hurricane city others hard...
# 3260                      green line derailment chicago
# 3261            meg issue hazardous weather outlook hwo
# 3262  cityofcalgary activated municipal emergency pl...
#
#                                   text_preprocessed_2nd
# 0                           happened terrible car crash
# 1     heard earthquake different city stay safe ever...
# 2     forest fire spot pond goose fleeing across str...
# 3                  apocalypse lighting spokane wildfire
# 4                    typhoon soudelor kill china taiwan
# ...                                                 ...
# 3258  earthquake safety los angeles safety fastener ...
# 3259  storm ri worse last hurricane city others hard...
# 3260                      green line derailment chicago
# 3261            meg issue hazardous weather outlook hwo
# 3262  cityofcalgary activated municipal emergency pl...
#
# [3263 rows x 6 columns]

# %%
# import train data
train_df = pd.read_csv('/content/preprocessed2nd_train_data.csv')
train_df.info()
train_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 6703 entries, 0 to 6702
# Data columns (total 7 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   id                     6703 non-null   int64
#  1   keyword                6703 non-null   object
#  2   location               6703 non-null   object
#  3   text                   6703 non-null   object
#  4   target                 6703 non-null   int64
#  5   text_preprocessed      6703 non-null   object
#  6   text_preprocessed_2nd  6703 non-null   object
# dtypes: int64(2), object(5)
# memory usage: 366.7+ KB
#          id keyword location  \
# 0         1    None     None
# 1         4    None     None
# 2         5    None     None
# 3         6    None     None
# 4         7    None     None
# ...     ...     ...      ...
# 6698  10863    None     None
# 6699  10864    None     None
# 6700  10866    None     None
# 6701  10869    None     None
# 6702  10873    None     None
#
#                                                    text  target  \
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 6698  #WorldNews Fallen powerlines on G:link tram: U...       1
# 6699  on the flip side I'm at Walmart and there is a...       1
# 6700  Suicide bomber kills 15 in Saudi security site...       1
# 6701  Two giant cranes holding a bridge collapse int...       1
# 6702  The Latest: More Homes Razed by Northern Calif...       1
#
#                                       text_preprocessed  \
# 0          deed reason earthquake may allah forgive you
# 1                 forest fire near la ronge sask canada
# 2     resident asked shelter place notified officer ...
# 3     people receive wildfire evacuation order calif...
# 4     got sent photo ruby alaska smoke wildfire pour...
# ...                                                 ...
# 6698  worldnews fallen powerlines g link tram update...
# 6699  flip side walmart bomb everyone evacuate stay ...
# 6700  suicide bomber kill saudi security site mosque...
# 6701  two giant crane holding bridge collapse nearby...
# 6702  latest home razed northern california wildfire...
#
#                                   text_preprocessed_2nd
# 0          deed reason earthquake may allah forgive you
# 1                 forest fire near la ronge sask canada
# 2     resident asked shelter place notified officer ...
# 3     people receive wildfire evacuation order calif...
# 4     got sent photo ruby alaska smoke wildfire pour...
# ...                                                 ...
# 6698  worldnews fallen powerlines g link tram update...
# 6699  flip side walmart bomb everyone evacuate stay ...
# 6700  suicide bomber kill saudi security site mosque...
# 6701  two giant crane holding bridge collapse nearby...
# 6702  latest home razed northern california wildfire...
#
# [6703 rows x 7 columns]

# %%
# check for missing data - train_df
train_df.isnull().sum()
# Out:
# id                       0
# keyword                  0
# location                 0
# text                     0
# target                   0
# text_preprocessed        0
# text_preprocessed_2nd    0
# dtype: int64

# %%
# check for missing data - test_df
test_df.isnull().sum()
# Out:
# id                       0
# keyword                  0
# location                 0
# text                     0
# text_preprocessed        0
# text_preprocessed_2nd    0
# dtype: int64

# %% [markdown]
# #### __Quick Look at data__

# %%
train_df[train_df['target'] == 0]['text_preprocessed_2nd'].values[1]
# Out:
# 'love fruit'

# %%
train_df[train_df['target'] == 1]['text_preprocessed_2nd'].values[1]
# Out:
# 'forest fire near la ronge sask canada'

# %% [markdown]
# #### __Building vectors__

# %%
count_vectorizer = feature_extraction.text.CountVectorizer()

# %%
train_vectors = count_vectorizer.fit_transform(train_df['text_preprocessed_2nd'])
train_vectors
# Out:
# <6703x11752 sparse matrix of type '<class 'numpy.int64'>'
# 	with 56033 stored elements in Compressed Sparse Row format>

# %%
test_vectors = count_vectorizer.transform(test_df['text_preprocessed_2nd'])
test_vectors
# Out:
# <3263x11752 sparse matrix of type '<class 'numpy.int64'>'
# 	with 24197 stored elements in Compressed Sparse Row format>

# %% [markdown]
# #### __Model__
# > - Ridge Classifier
# > - Logistic Regression
# > - Gausian NB
# > - SGD Calssifier
# > - KNN
# > - SVC Classifier
# > - Decision Tree
# > - Random Forest
# > - XGBoost
# > - Gradient Boopsting Classifer

# %%
from sklearn.linear_model import LogisticRegression, RidgeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.linear_model import SGDClassifier
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC
from sklearn import svm
from sklearn import tree
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
import xgboost as xgb
from xgboost import XGBClassifier
from sklearn.ensemble import GradientBoostingClassifier

# %%
## Train classification models
clf_ridge = RidgeClassifier()
clf_lg = LogisticRegression()
clf_nb = GaussianNB()
clf_sgd = SGDClassifier()
clf_knn = KNeighborsClassifier()
clf_svc = SVC()
clf_dt = DecisionTreeClassifier()
clf_rf = RandomForestClassifier()
clf_xgb = XGBClassifier()

# make a list of the above models
classification_models = [clf_ridge, clf_lg, clf_nb, clf_sgd,
                         clf_knn, clf_svc, clf_dt, clf_rf, clf_xgb]
classification_models
# Out:
# [RidgeClassifier(),
#  LogisticRegression(),
#  GaussianNB(),
#  SGDClassifier(),
#  KNeighborsClassifier(),
#  SVC(),
#  DecisionTreeClassifier(),
#  RandomForestClassifier(),
#  XGBClassifier()]

# %%
# Functions for f1 calculation

# functions to run all models being trained
def run_model(model, train_vectors, data):
  scores_f1 = model_selection.cross_val_score(model, train_vectors, data, cv=5, scoring='f1')
  
  return scores_f1

def run_mean_model(model, train_vectors, data):
  scores_f1 = model_selection.cross_val_score(model, train_vectors, data, cv=5, scoring='f1')
    
  return np.mean(scores_f1)

# function for summarizing model performance
def summary_ml(models_lst, train_vectors, data):

    # set up empty lists for arrays of scores for models
    ridge = []
    lg = []
    nb = []
    sgd = []
    knn = []
    svc = []
    dt = []
    rf = []
    xgb = []
    
    models_result = [ridge, lg, nb, sgd, knn, svc, dt, rf, xgb]
    
    for model in range(len(models_lst)):
        f1 = run_model(models_lst[model], train_vectors, data)
        models_result[model].append(f1)
   
        
    dict_model = {'ridge': ridge, 'logisticReg': lg, 'gausian nb': nb,
                  'sgd': sgd, 'knn': knn, 'svc': svc, 'decision tree': dt,
                  'random forest': rf, 'xgb': xgb}
    
    # set up empty lists for mean scores for models
    ridge_m = []
    lg_m = []
    nb_m = []
    sgd_m = []
    knn_m = []
    svc_m = []
    dt_m = []
    rf_m = []
    xgb_m = []

    models_result_mean = [ridge_m, lg_m, nb_m, sgd_m, knn_m, svc_m, dt_m, rf_m, xgb_m]
    
    for model in range(len(models_lst)):
        f1m = run_mean_model(models_lst[model], train_vectors, data)
        models_result_mean[model].append(f1m)
    
    dict_mean_model = {'ridge': ridge_m, 'logisticReg': lg_m, 'gausian nb': nb_m,
                  'sgd': sgd_m, 'knn': knn_m, 'svc': svc_m, 'decision tree': dt_m,
                  'random forest': rf_m, 'xgb': xgb_m}
    
    result_df = pd.DataFrame(dict_model)
    result_sum_df = pd.DataFrame(dict_mean_model)
    
    return result_df, result_sum_df

# %%
# Functions for accuracy calculation

# functions to run all models being trained
def run_model_acc(model, train_vectors, data):
  scores_acc = model_selection.cross_val_score(model, train_vectors, data, cv=5, scoring='accuracy')
  
  return scores_acc

def run_mean_model_acc(model, train_vectors, data):
    scores_acc = model_selection.cross_val_score(model, train_vectors, data, cv=5, scoring='accuracy')
    
    return np.mean(scores_acc)

# function for summarizing model performance
def summary_ml_acc(models_lst, train_vectors, data):

    # set up empty lists for arrays of scores for models
    ridge = []
    lg = []
    nb = []
    sgd = []
    knn = []
    svc = []
    dt = []
    rf = []
    xgb = []
    
    models_result = [ridge, lg, nb, sgd, knn, svc, dt, rf, xgb]
    
    for model in range(len(models_lst)):
        acc = run_model_acc(models_lst[model], train_vectors, data)
        models_result[model].append(acc)
    
        
    dict_model = {'ridge': ridge, 'logisticReg': lg, 'gausian nb': nb,
                  'sgd': sgd, 'knn': knn, 'svc': svc, 'decision tree': dt,
                  'random forest': rf, 'xgb': xgb}
    
    # set up empty lists for mean scores for models
    ridge_m = []
    lg_m = []
    nb_m = []
    sgd_m = []
    knn_m = []
    svc_m = []
    dt_m = []
    rf_m = []
    xgb_m = []

    models_result_mean = [ridge_m, lg_m, nb_m, sgd_m, knn_m, svc_m, dt_m, rf_m, xgb_m]
    
    for model in range(len(models_lst)):
        accm = run_mean_model_acc(models_lst[model], train_vectors, data)
        models_result_mean[model].append(accm)
    
    dict_mean_model = {'ridge': ridge_m, 'logisticReg': lg_m, 'gausian nb': nb_m,
                  'sgd': sgd_m, 'knn': knn_m, 'svc': svc_m, 'decision tree': dt_m,
                  'random forest': rf_m, 'xgb': xgb_m}
    
    result_df = pd.DataFrame(dict_model)
    result_sum_df = pd.DataFrame(dict_mean_model)
    
    return result_df, result_sum_df

# %%
# start time to measure the time of the program execution
start_time = time.time()

# print out the results of the model performance summaries
print('\nf1 scores:\n')
result_array, summary_mean_result = summary_ml(classification_models, train_vectors, train_df['target'])
result_array
summary_mean_result

print('\naccuracy scores:\n')
result_array_acc, summary_mean_result_acc = summary_ml_acc(classification_models, train_vectors, train_df['target'])
result_array_acc
summary_mean_result_acc

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# f1 scores:
#                                                ridge  \
# 0  [0.6564195298372514, 0.5022502250225022, 0.579...
#
#                                          logisticReg  \
# 0  [0.671573137074517, 0.5892700087950747, 0.6402...
#
#                   gausian nb  \
# 0  [nan, nan, nan, nan, nan]
#
#                                                  sgd  \
# 0  [0.6452205882352942, 0.5544899738448125, 0.611...
#
#                                                  knn  \
# 0  [0.20652173913043476, 0.17158931082981715, 0.1...
#
#                                                  svc  \
# 0  [0.6360078277886496, 0.5719661335841957, 0.632...
#
#                                        decision tree  \
# 0  [0.5521235521235521, 0.46767050487156775, 0.56...
#
#                                        random forest  \
# 0  [0.5950248756218905, 0.5191111111111111, 0.596...
#
#                                                  xgb
# 0  [0.47821229050279324, 0.39111111111111113, 0.4...
#       ridge  logisticReg  gausian nb       sgd       knn       svc  \
# 0  0.596553     0.642635         NaN  0.607973  0.178792  0.630763
#
#    decision tree  random forest       xgb
# 0       0.545762       0.581318  0.429587
# accuracy scores:
#                                                ridge  \
# 0  [0.7166293810589113, 0.5876211782252051, 0.621...
#
#                                          logisticReg  \
# 0  [0.7337807606263982, 0.6517524235645041, 0.674...
#
#                   gausian nb  \
# 0  [nan, nan, nan, nan, nan]
#
#                                                  sgd  \
# 0  [0.7166293810589113, 0.6211782252050708, 0.646...
#
#                                                  knn  \
# 0  [0.5645041014168531, 0.5607755406413124, 0.541...
#
#                                                  svc  \
# 0  [0.7225950782997763, 0.6607009694258016, 0.686...
#
#                                        decision tree  \
# 0  [0.6495152870991797, 0.5525727069351231, 0.595...
#
#                                        random forest  \
# 0  [0.7017151379567487, 0.609992542878449, 0.6360...
#
#                                                  xgb
# 0  [0.6517524235645041, 0.5913497390007457, 0.590...
#       ridge  logisticReg  gausian nb       sgd       knn       svc  \
# 0  0.652996     0.696409         NaN  0.660154  0.556617  0.705512
#
#    decision tree  random forest       xgb
# 0       0.601969       0.648965  0.617935
# --- 400.69480419158936 seconds ---

# %%
# start time to measure the time of the program execution
start_time = time.time()

## Train classification models
clf_gb = GradientBoostingClassifier()

# functions to run all models being trained
print('\nf1 scores:\n')
run_model(clf_gb, train_vectors, train_df['target'])
print('\n')
run_mean_model(clf_gb, train_vectors, train_df['target'])
print('\n')
print('\naccuracy scores:\n')
run_model_acc(clf_gb, train_vectors, train_df['target'])
print('\n')
run_mean_model_acc(clf_gb, train_vectors, train_df['target'])

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# f1 scores:
# array([0.48168701, 0.38955386, 0.46452867, 0.3559322 , 0.54802831])
# 0.4540830954608497
# accuracy scores:
# array([0.65697241, 0.57196122, 0.58836689, 0.60597015, 0.6619403 ])
# 0.6177874609057621
# --- 91.0231420993805 seconds ---

# %% [markdown]
# ### __No Hyperparameter Tuning - Logistic Regression__

# %%
clf_lg.fit(train_vectors, train_df['target'])
# Out:
# LogisticRegression()

# %%
# start time to measure the time of the program execution
start_time = time.time()

submission = pd.read_csv('/content/sample_submission.csv')
submission['target'] = clf_lg.predict(test_vectors)
submission.to_csv('trial18_submission_clf_lg.csv', index=False)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# --- 0.008881568908691406 seconds ---

# %% [markdown]
# #### __No Hyperparameter Tuning - SVC__

# %%
clf_svc.fit(train_vectors, train_df['target'])
# Out:
# SVC()

# %%
# start time to measure the time of the program execution
start_time = time.time()

submission = pd.read_csv('/content/sample_submission.csv')
submission['target'] = clf_svc.predict(test_vectors)
submission.to_csv('trial19_submission_clf_svc.csv', index=False)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# --- 1.8752822875976562 seconds ---

# %% [markdown]
# ### __Hyperparameter Tuning - SVC__
# > - https://stackoverflow.com/questions/57513586/how-to-use-grid-search-for-the-svm
# > - https://scikit-learn.org/stable/modules/generated/sklearn.svm.SVC.html
# > - https://www.geeksforgeeks.org/svm-hyperparameter-tuning-using-gridsearchcv-ml/
# > - https://towardsdatascience.com/machine-learning-with-python-classification-complete-tutorial-d2c99dc524ec

# %%
# start time to measure the time of the program execution
start_time = time.time()

# explicitly require this experimental feature
from sklearn.experimental import enable_halving_search_cv # noqa
# now you can import normally from model_selection
from sklearn.model_selection import HalvingGridSearchCV

# defining parameter range
param_grid = {'C': [0.1, 1, 10, 100, 1000],
              'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
              'kernel': ['linear', 'rbf'],
             'max_iter': [-1],
             'random_state': [10, 25, 35, 42, 53]}
 
grid_svc = HalvingGridSearchCV(SVC(), param_grid, refit = True, verbose = 3)
 
# fitting the model for grid search
grid_svc.fit(train_vectors, train_df['target'])

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# n_iterations: 6
# n_required_iterations: 6
# n_possible_iterations: 6
# min_resources_: 27
# max_resources_: 6703
# aggressive_elimination: False
# factor: 3
# ----------
# iter: 0
# n_candidates: 250
# n_resources: 27
# Fitting 5 folds for each of 250 candidates, totalling 1250 fits
# [CV 1/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.857, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.952, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.200) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.905, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=0.400) total time=   0.0s
# [CV 4/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 5/5] END C=0.1, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.619, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.952, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=25;, score=(train=0.952, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=35;, score=(train=0.952, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=42;, score=(train=0.952, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.1, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.952, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=42;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.400) total time=   0.0s
# [CV 4/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.600) total time=   0.0s
# [CV 5/5] END C=1, gamma=0.01, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=1.000) total time=   0.0s
# [CV 1/5] END C=1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.714, test=0.000) total time=   0.0s
# [CV 2/5] END C=1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.524, test=0.400) total time=   0.0s
# [CV 3/5] END C=1, gamma=0.01, kernel=rbf, max_iter=-1, random_state=10;, score=(train=0.619, test=0.400) total time=   0.0s
# ...
# [CV 1/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 3/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 4/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.995, test=0.667) total time=   0.0s
# [CV 5/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 1/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 3/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 4/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.995, test=0.667) total time=   0.0s
# [CV 5/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 1/5] END C=10, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5] END C=10, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 3/5] END C=10, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 4/5] END C=10, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.995, test=0.667) total time=   0.0s
# [CV 5/5] END C=10, gamma=0.0001, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 1/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 3/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 4/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.995, test=0.667) total time=   0.0s
# [CV 5/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 1/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 3/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 4/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.995, test=0.667) total time=   0.0s
# [CV 5/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=25;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 1/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 3/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 4/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.995, test=0.667) total time=   0.0s
# [CV 5/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=35;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 1/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.646) total time=   0.0s
# [CV 3/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 4/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.995, test=0.667) total time=   0.0s
# [CV 5/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=1.000, test=0.604) total time=   0.0s
# [CV 1/5] END C=1000, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.792) total time=   0.0s
# [CV 2/5] END C=1000, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.990, test=0.646) total time=   0.0s
# [CV 3/5] END C=1000, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.995, test=0.521) total time=   0.0s
# [CV 4/5] END C=1000, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=0.995, test=0.688) total time=   0.0s
# [CV 5/5] END C=1000, gamma=0.0001, kernel=rbf, max_iter=-1, random_state=53;, score=(train=1.000, test=0.625) total time=   0.0s
# ----------
# iter: 3
# n_candidates: 10
# n_resources: 729
# Fitting 5 folds for each of 10 candidates, totalling 50 fits
# [CV 1/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=35;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=10, gamma=1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=10;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=100, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.997, test=0.676) total time=   0.0s
# [CV 1/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.998, test=0.655) total time=   0.0s
# [CV 2/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.993, test=0.634) total time=   0.0s
# [CV 3/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.997, test=0.586) total time=   0.0s
# [CV 4/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.991, test=0.593) total time=   0.0s
# [CV 5/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.997, test=0.676) total time=   0.0s
# ----------
# iter: 4
# n_candidates: 4
# n_resources: 2187
# Fitting 5 folds for each of 4 candidates, totalling 20 fits
# [CV 1/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.993, test=0.682) total time=   0.3s
# [CV 2/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.991, test=0.641) total time=   0.3s
# [CV 3/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.993, test=0.648) total time=   0.3s
# [CV 4/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.995, test=0.609) total time=   0.4s
# [CV 5/5] END C=100, gamma=1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.991, test=0.670) total time=   0.3s
# [CV 1/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.993, test=0.682) total time=   0.3s
# [CV 2/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.991, test=0.641) total time=   0.3s
# [CV 3/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.993, test=0.648) total time=   0.3s
# [CV 4/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.995, test=0.609) total time=   0.4s
# [CV 5/5] END C=10, gamma=0.01, kernel=linear, max_iter=-1, random_state=25;, score=(train=0.991, test=0.670) total time=   0.3s
# [CV 1/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.993, test=0.682) total time=   0.3s
# [CV 2/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.991, test=0.641) total time=   0.3s
# [CV 3/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.993, test=0.648) total time=   0.3s
# [CV 4/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.995, test=0.609) total time=   0.4s
# [CV 5/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.991, test=0.670) total time=   0.4s
# [CV 1/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.993, test=0.682) total time=   0.4s
# [CV 2/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.991, test=0.641) total time=   0.4s
# [CV 3/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.993, test=0.648) total time=   0.3s
# [CV 4/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.995, test=0.609) total time=   0.4s
# [CV 5/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.991, test=0.670) total time=   0.3s
# ----------
# iter: 5
# n_candidates: 2
# n_resources: 6561
# Fitting 5 folds for each of 2 candidates, totalling 10 fits
# [CV 1/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.987, test=0.690) total time=   2.9s
# [CV 2/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.986, test=0.601) total time=   2.7s
# [CV 3/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.987, test=0.627) total time=   2.8s
# [CV 4/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.988, test=0.617) total time=   2.8s
# [CV 5/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53;, score=(train=0.986, test=0.684) total time=   3.9s
# [CV 1/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.987, test=0.690) total time=   2.8s
# [CV 2/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.986, test=0.601) total time=   2.8s
# [CV 3/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.987, test=0.627) total time=   2.8s
# [CV 4/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.988, test=0.617) total time=   2.8s
# [CV 5/5] END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=42;, score=(train=0.986, test=0.684) total time=   3.9s
# HalvingGridSearchCV(estimator=SVC(),
#                     param_grid={'C': [0.1, 1, 10, 100, 1000],
#                                 'gamma': [1, 0.1, 0.01, 0.001, 0.0001],
#                                 'kernel': ['linear', 'rbf'], 'max_iter': [-1],
#                                 'random_state': [10, 25, 35, 42, 53]},
#                     verbose=3)
# --- 68.04360890388489 seconds ---

# %%
# start time to measure the time of the program execution
start_time = time.time()

# print best parameter after tuning
print(grid_svc.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid_svc.best_estimator_)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# {'C': 10, 'gamma': 0.1, 'kernel': 'linear', 'max_iter': -1, 'random_state': 53}
# SVC(C=10, gamma=0.1, kernel='linear', random_state=53)
#
#
# --- 0.0008373260498046875 seconds ---

# %% [markdown]
# #### END C=10, gamma=0.1, kernel=linear, max_iter=-1, random_state=53

# %%
# start time to measure the time of the program execution
start_time = time.time()

# set up LG model with the best paramter from grid search above
clf_svc2 = SVC(C=10, gamma=0.1, kernel='linear', max_iter=-1,
                            random_state=53)

# check the trained scores
print('\nf1 scores:\n')
run_model(clf_svc2, train_vectors, train_df['target'])
run_mean_model(clf_svc2, train_vectors, train_df['target'])

print('\n')
print('\naccuracy scores:\n')
run_model_acc(clf_svc2, train_vectors, train_df['target'])
run_mean_model_acc(clf_svc2, train_vectors, train_df['target'])

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# f1 scores:
# array([0.62522202, 0.5407279 , 0.57942387, 0.51691729, 0.68181818])
# 0.5888218542354161
# accuracy scores:
# array([0.68530947, 0.60477256, 0.61894109, 0.61641791, 0.69701493])
# 0.6444911905795407
# --- 56.07453918457031 seconds ---

# %%
# start time to measure the time of the program execution
start_time = time.time()

submission = pd.read_csv('/content/sample_submission.csv')
submission['target'] = grid_svc.predict(test_vectors)
submission.to_csv('trial20_submission_grid_svc2.csv', index=False)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# --- 0.8098781108856201 seconds ---

# %% [markdown]
# ### __Hyperparameter Tuning - Logistic Regression__
# > - https://machinelearningmastery.com/hyperparameters-for-classification-machine-learning-algorithms/
# > - https://scikit-learn.org/stable/modules/generated/sklearn.linear_model.LogisticRegression.html

# %%
# start time to measure the time of the program execution
start_time = time.time()

from sklearn.datasets import make_blobs
from sklearn.model_selection import RepeatedStratifiedKFold
# explicitly require this experimental feature

# defining parameter range
param_grid = {'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag', 'saga'],
              'penalty': ['l2'],
             'C': [0.01, 0.1, 1, 10, 100, 1000],
             'random_state': [10, 25, 35, 42, 53]}
 
cv = RepeatedStratifiedKFold(n_splits=10, n_repeats=3)
grid_lg = GridSearchCV(LogisticRegression(), param_grid, n_jobs=-1, 
                       scoring='f1', cv=cv, verbose = 3)
    
# fitting the model for grid search
grid_lg.fit(train_vectors, train_df['target'])

# print best parameter after tuning
print(grid_lg.best_params_)
 
# print how our model looks after hyper-parameter tuning
print(grid_lg.best_estimator_)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# Fitting 30 folds for each of 150 candidates, totalling 4500 fits
# GridSearchCV(cv=RepeatedStratifiedKFold(n_repeats=3, n_splits=10, random_state=None),
#              estimator=LogisticRegression(), n_jobs=-1,
#              param_grid={'C': [0.01, 0.1, 1, 10, 100, 1000], 'penalty': ['l2'],
#                          'random_state': [10, 25, 35, 42, 53],
#                          'solver': ['newton-cg', 'lbfgs', 'liblinear', 'sag',
#                                     'saga']},
#              scoring='f1', verbose=3)
# {'C': 1, 'penalty': 'l2', 'random_state': 10, 'solver': 'liblinear'}
# LogisticRegression(C=1, random_state=10, solver='liblinear')
#
#
# --- 42.927711725234985 seconds ---

# %%
# start time to measure the time of the program execution
start_time = time.time()

# set up LG model with the best paramter from grid search above
clf_lg2 = LogisticRegression(C=1, penalty='l2', 
                            random_state=10, solver='liblinear')

# check the trained scores
print('\nf1 scores:\n')
run_model(clf_lg2, train_vectors, train_df['target'])
print('\n')
run_mean_model(clf_lg2, train_vectors, train_df['target'])

print('\n')
print('\naccuracy scores:\n')
run_model_acc(clf_lg2, train_vectors, train_df['target'])
print('\n')
run_mean_model_acc(clf_lg2, train_vectors, train_df['target'])

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# f1 scores:
# array([0.67034991, 0.58947368, 0.64309211, 0.56614786, 0.74479568])
# 0.6427718479317405
# accuracy scores:
# array([0.73303505, 0.65100671, 0.67636092, 0.66716418, 0.75298507])
# 0.6961103876590203
# --- 1.0926017761230469 seconds ---

# %%
# start time to measure the time of the program execution
start_time = time.time()

submission = pd.read_csv('/content/sample_submission.csv')
submission['target'] = grid_lg.predict(test_vectors)
submission.to_csv('trial21_submission_grid_lg2.csv', index=False)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# --- 0.009535074234008789 seconds ---
