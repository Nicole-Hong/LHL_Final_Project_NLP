# %% [markdown]
# ### __NLP Disaster Tweets: Sentiment Analysis with Pre-trained Model, Vader__
#
# NLP Reference Links:
# > - https://pub.towardsai.net/ai-sustainability-tweets-sentiment-analysis-using-pre-trained-models-8669f8ba70ed
# > - NLTK Library of Pre-trained Models: http://www.nltk.org/nltk_data/
# > - GitHub for Vedar: https://github.com/cjhutto/vaderSentiment
#
# Other Reference Links:
# > - https://www.interviewqs.com/ddi-code-snippets/drop-duplicate-rows-pandas
# > - https://seaborn.pydata.org/examples/index.html
# > - https://seaborn.pydata.org/tutorial/axis_grids.html
# > - https://www.delftstack.com/howto/seaborn/size-of-seaborn-plot/
# > - https://drawingfromdata.com/pandas/seaborn/matplotlib/visualization/setting-figure-size-matplotlib-seaborn.html
#
# Colormap:
# > - matplotlib: https://matplotlib.org/stable/gallery/color/colormap_reference.html
# > - seaborn: https://seaborn.pydata.org/tutorial/color_palettes.html

# %%
# !pip install matplotlib --upgrade
# Out:
# Requirement already satisfied: matplotlib in /usr/local/lib/python3.7/dist-packages (3.2.2)
# Collecting matplotlib
#   Downloading matplotlib-3.5.1-cp37-cp37m-manylinux_2_5_x86_64.manylinux1_x86_64.whl (11.2 MB)
#      |████████████████████████████████| 11.2 MB 15.1 MB/s
# Requirement already satisfied: pyparsing>=2.2.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (3.0.8)
# Requirement already satisfied: kiwisolver>=1.0.1 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.4.2)
# Requirement already satisfied: packaging>=20.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (21.3)
# Requirement already satisfied: pillow>=6.2.0 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (7.1.2)
# Collecting fonttools>=4.22.0
#   Downloading fonttools-4.33.2-py3-none-any.whl (930 kB)
#      |████████████████████████████████| 930 kB 59.8 MB/s
# Requirement already satisfied: cycler>=0.10 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (0.11.0)
# Requirement already satisfied: python-dateutil>=2.7 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (2.8.2)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.7/dist-packages (from matplotlib) (1.21.6)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.7/dist-packages (from kiwisolver>=1.0.1->matplotlib) (4.1.1)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.7/dist-packages (from python-dateutil>=2.7->matplotlib) (1.15.0)
# Installing collected packages: fonttools, matplotlib
#   Attempting uninstall: matplotlib
#     Found existing installation: matplotlib 3.2.2
#     Uninstalling matplotlib-3.2.2:
#       Successfully uninstalled matplotlib-3.2.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# albumentations 0.1.12 requires imgaug<0.2.7,>=0.2.5, but you have imgaug 0.2.9 which is incompatible.
# Successfully installed fonttools-4.33.2 matplotlib-3.5.1

# %%
import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)
import time

import re
import string
import numpy as np 
import random
import pandas as pd 
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
from plotly import graph_objs as go
import plotly.express as px
import plotly.figure_factory as ff
from collections import Counter

from PIL import Image
from wordcloud import WordCloud, STOPWORDS, ImageColorGenerator


import nltk
nltk.download('punkt')
from nltk.corpus import stopwords
from nltk.tokenize import word_tokenize

from tqdm import tqdm
import os
import nltk
import spacy
import random
from spacy.util import compounding
from spacy.util import minibatch

from collections import defaultdict
from collections import Counter

import keras
from keras.models import Sequential
from keras.initializers import Constant
from keras.layers import (LSTM, 
                          Embedding, 
                          BatchNormalization,
                          Dense, 
                          TimeDistributed, 
                          Dropout, 
                          Bidirectional,
                          Flatten, 
                          GlobalMaxPool1D)
from keras.preprocessing.text import Tokenizer
from keras.preprocessing.sequence import pad_sequences
from keras.layers.embeddings import Embedding
from keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.optimizers import Adam

from sklearn.metrics import (
    precision_score, 
    recall_score, 
    f1_score, 
    classification_report,
    accuracy_score
)

# to be able to see multiple ouputs from sungle cell
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"
# Out:
# [nltk_data] Downloading package punkt to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package punkt is already up-to-date!

# %% [markdown]
# #### __Load Datasets__
#   * Only using train data, as it is labeled (i.e. disaster- or non-disaster related tweets), while test data is not labeled

# %%
# import train data
train_df = pd.read_csv('../data/train.csv')
train_df.info()
train_df
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   id        7613 non-null   int64
#  1   keyword   7552 non-null   object
#  2   location  5080 non-null   object
#  3   text      7613 non-null   object
#  4   target    7613 non-null   int64
# dtypes: int64(2), object(3)
# memory usage: 297.5+ KB
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
# [7613 rows x 5 columns]

# %% [markdown]
# #### __Pre-Trained Model: Vader_Lexicon__

# %%
#nltk.download()
import nltk
nltk.download('vader_lexicon')

from nltk.sentiment.vader import SentimentIntensityAnalyzer
sentiment = SentimentIntensityAnalyzer()
# Out:
# [nltk_data] Downloading package vader_lexicon to
# [nltk_data]     C:\Users\User\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!
# True

# %%
# test sentiment analysis
text_test = train_df['text'][0]
print(f'\n{text_test}\n')
sentiment.polarity_scores(text_test)
# Out:
# Our Deeds are the Reason of this #earthquake May ALLAH Forgive us all
# {'neg': 0.0, 'neu': 0.851, 'pos': 0.149, 'compound': 0.2732}

# %%
# function to convert dictionary output to list output
def dict_converter(dict1):
  dictlist = list()
  for key, value in dict1.items():
    temp = [key,value]
    dictlist.append(temp)
  return dictlist

#example
dict_converter({'compound': 0.2732, 'neg': 0.0, 'neu': 0.851, 'pos': 0.149})
# Out:
# [['compound', 0.2732], ['neg', 0.0], ['neu', 0.851], ['pos', 0.149]]

# %%
dict_converter({'compound': 0.2732, 'neg': 0.0, 'neu': 0.851, 'pos': 0.149})[0][1]
# Out:
# 0.2732

# %% [markdown]
# #### __Sentiment Analysis__

# %%
# start time to measure the time of the program execution
start_time = time.time()

tweets = list()

for g in train_df['text']:
  dict_res = dict_converter(sentiment.polarity_scores(g))
  tweets.append([g, dict_res[0][1], dict_res[1][1], dict_res[2][1], dict_res[3][1]])

# make tweets lists above to datarame
tweets = pd.DataFrame(tweets, columns=['text', 'neg', 'neu', 'pos', 'compound'])
tweets.info()
tweets

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 5 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   text      7613 non-null   object
#  1   neg       7613 non-null   float64
#  2   neu       7613 non-null   float64
#  3   pos       7613 non-null   float64
#  4   compound  7613 non-null   float64
# dtypes: float64(4), object(1)
# memory usage: 297.5+ KB
#                                                    text    neg    neu    pos  \
# 0     Our Deeds are the Reason of this #earthquake M...  0.000  0.851  0.149
# 1                Forest fire near La Ronge Sask. Canada  0.286  0.714  0.000
# 2     All residents asked to 'shelter in place' are ...  0.095  0.905  0.000
# 3     13,000 people receive #wildfires evacuation or...  0.000  1.000  0.000
# 4     Just got sent this photo from Ruby #Alaska as ...  0.000  1.000  0.000
# ...                                                 ...    ...    ...    ...
# 7608  Two giant cranes holding a bridge collapse int...  0.262  0.738  0.000
# 7609  @aria_ahrary @TheTawniest The out of control w...  0.166  0.834  0.000
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...  0.000  1.000  0.000
# 7611  Police investigating after an e-bike collided ...  0.345  0.655  0.000
# 7612  The Latest: More Homes Razed by Northern Calif...  0.000  1.000  0.000
#
#       compound
# 0       0.2732
# 1      -0.3400
# 2      -0.2960
# 3       0.0000
# 4       0.0000
# ...        ...
# 7608   -0.4939
# 7609   -0.5849
# 7610    0.0000
# 7611   -0.7845
# 7612    0.0000
#
# [7613 rows x 5 columns]
# --- 3.7742581367492676 seconds ---

# %%
# start time to measure the time of the program execution
start_time = time.time()

# Add the result of sentiment analysis to train data
train_df['sentiment_neg'] = tweets['neg']
train_df['sentiment_neu'] = tweets['neu']
train_df['sentiment_pos'] = tweets['pos']
train_df['sentiment_compound'] = tweets['compound']

# check
train_df.info()
train_df

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 7613 entries, 0 to 7612
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  7613 non-null   int64
#  1   keyword             7552 non-null   object
#  2   location            5080 non-null   object
#  3   text                7613 non-null   object
#  4   target              7613 non-null   int64
#  5   sentiment_neg       7613 non-null   float64
#  6   sentiment_neu       7613 non-null   float64
#  7   sentiment_pos       7613 non-null   float64
#  8   sentiment_compound  7613 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 535.4+ KB
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7608  10869     NaN      NaN
# 7609  10870     NaN      NaN
# 7610  10871     NaN      NaN
# 7611  10872     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target  \
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7609  @aria_ahrary @TheTawniest The out of control w...       1
# 7610  M1.94 [01:04 UTC]?5km S of Volcano Hawaii. htt...       1
# 7611  Police investigating after an e-bike collided ...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound
# 0             0.000          0.851          0.149              0.2732
# 1             0.286          0.714          0.000             -0.3400
# 2             0.095          0.905          0.000             -0.2960
# 3             0.000          1.000          0.000              0.0000
# 4             0.000          1.000          0.000              0.0000
# ...             ...            ...            ...                 ...
# 7608          0.262          0.738          0.000             -0.4939
# 7609          0.166          0.834          0.000             -0.5849
# 7610          0.000          1.000          0.000              0.0000
# 7611          0.345          0.655          0.000             -0.7845
# 7612          0.000          1.000          0.000              0.0000
#
# [7613 rows x 9 columns]
# --- 0.061760902404785156 seconds ---

# %%
# drop duplicate tweets and check shape before/after

# start time to measure the time of the program execution
start_time = time.time()

# before dropping duplicates
print('\n', train_df.shape)
print('\n')

# drop a duplicate row, based on column name
train_df = train_df.drop_duplicates(subset='text', keep="first")

# after dropping duplicates
print('\n', train_df.shape)

# check
train_df.info()
train_df

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
#  (7613, 9)
#
#
#
#  (7503, 9)
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7503 entries, 0 to 7612
# Data columns (total 9 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  7503 non-null   int64
#  1   keyword             7447 non-null   object
#  2   location            5021 non-null   object
#  3   text                7503 non-null   object
#  4   target              7503 non-null   int64
#  5   sentiment_neg       7503 non-null   float64
#  6   sentiment_neu       7503 non-null   float64
#  7   sentiment_pos       7503 non-null   float64
#  8   sentiment_compound  7503 non-null   float64
# dtypes: float64(4), int64(2), object(3)
# memory usage: 586.2+ KB
#          id keyword location  \
# 0         1     NaN      NaN
# 1         4     NaN      NaN
# 2         5     NaN      NaN
# 3         6     NaN      NaN
# 4         7     NaN      NaN
# ...     ...     ...      ...
# 7604  10863     NaN      NaN
# 7605  10864     NaN      NaN
# 7606  10866     NaN      NaN
# 7608  10869     NaN      NaN
# 7612  10873     NaN      NaN
#
#                                                    text  target  \
# 0     Our Deeds are the Reason of this #earthquake M...       1
# 1                Forest fire near La Ronge Sask. Canada       1
# 2     All residents asked to 'shelter in place' are ...       1
# 3     13,000 people receive #wildfires evacuation or...       1
# 4     Just got sent this photo from Ruby #Alaska as ...       1
# ...                                                 ...     ...
# 7604  #WorldNews Fallen powerlines on G:link tram: U...       1
# 7605  on the flip side I'm at Walmart and there is a...       1
# 7606  Suicide bomber kills 15 in Saudi security site...       1
# 7608  Two giant cranes holding a bridge collapse int...       1
# 7612  The Latest: More Homes Razed by Northern Calif...       1
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound
# 0             0.000          0.851          0.149              0.2732
# 1             0.286          0.714          0.000             -0.3400
# 2             0.095          0.905          0.000             -0.2960
# 3             0.000          1.000          0.000              0.0000
# 4             0.000          1.000          0.000              0.0000
# ...             ...            ...            ...                 ...
# 7604          0.249          0.751          0.000             -0.6841
# 7605          0.122          0.878          0.000             -0.4939
# 7606          0.328          0.574          0.098             -0.7650
# 7608          0.262          0.738          0.000             -0.4939
# 7612          0.000          1.000          0.000              0.0000
#
# [7503 rows x 9 columns]
# --- 0.1192631721496582 seconds ---

# %% [markdown]
# #### __Order Tweets by the scores from the most positive to the most negative__

# %%
# start time to measure the time of the program execution
start_time = time.time()

train_df = train_df.sort_values(['sentiment_compound'], ascending=False)
train_df

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
#          id           keyword           location  \
# 6992  10028           twister                NaN
# 6534   9345          survived         Texas, USA
# 6292   8989             storm                NaN
# 3163   4541         emergency  Renfrew, Scotland
# 6778   9710           tragedy                NaN
# ...     ...               ...                ...
# 6407   9159  suicide%20bomber          Worldwide
# 6393   9137    suicide%20bomb          Worldwide
# 6411   9166  suicide%20bomber                NaN
# 6414   9172  suicide%20bomber                NaN
# 7472  10689             wreck                NaN
#
#                                                    text  target  \
# 6992  Check out 'Want Twister Tickets AND A VIP EXPE...       0
# 6534  @thoutaylorbrown I feel like accidents are jus...       0
# 6292  TodayÛªs storm will pass; let tomorrowÛªs li...       1
# 3163  @batfanuk we enjoyed the show today. Great fun...       0
# 6778  Maaaaan I love Love Without Tragedy by @rihann...       0
# ...                                                 ...     ...
# 6407  17 killed in SÛªArabia mosque suicide bombing...       1
# 6393  ? 19th Day Since 17-Jul-2015 -- Nigeria: Suici...       1
# 6411  Suicide bomber kills 15 in Saudi security site...       1
# 6414  @Abu_Baraa1 Suicide bomber targets Saudi mosqu...       1
# 7472  wreck? wreck wreck wreck wreck wreck wreck wre...       0
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound
# 6992          0.000          0.402          0.598              0.9730
# 6534          0.049          0.412          0.539              0.9564
# 6292          0.000          0.509          0.491              0.9471
# 3163          0.084          0.354          0.563              0.9423
# 6778          0.000          0.381          0.619              0.9394
# ...             ...            ...            ...                 ...
# 6407          0.579          0.421          0.000             -0.9552
# 6393          0.583          0.417          0.000             -0.9595
# 6411          0.536          0.400          0.064             -0.9623
# 6414          0.542          0.458          0.000             -0.9686
# 7472          1.000          0.000          0.000             -0.9883
#
# [7503 rows x 9 columns]
# --- 0.03233933448791504 seconds ---

# %%
print(f"Min: {min(train_df['sentiment_compound'])}")
print(f"Max: {max(train_df['sentiment_compound'])}")
# Out:
# Min: -0.9883
# Max: 0.973

# %%
# start time to measure the time of the program execution
start_time = time.time()

# count the positive, neutral and negative sentiment
sentiment = []

for score in train_df['sentiment_compound']:
  if score >= 0.05:
    sentiment.append('positive')
  elif score <= -0.05:
    sentiment.append('negative')
  else:
    sentiment.append('neutral')

train_df['sentiment'] = sentiment

# check
train_df.info()
train_df

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7503 entries, 6992 to 7472
# Data columns (total 10 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  7503 non-null   int64
#  1   keyword             7447 non-null   object
#  2   location            5021 non-null   object
#  3   text                7503 non-null   object
#  4   target              7503 non-null   int64
#  5   sentiment_neg       7503 non-null   float64
#  6   sentiment_neu       7503 non-null   float64
#  7   sentiment_pos       7503 non-null   float64
#  8   sentiment_compound  7503 non-null   float64
#  9   sentiment           7503 non-null   object
# dtypes: float64(4), int64(2), object(4)
# memory usage: 644.8+ KB
#          id           keyword           location  \
# 6992  10028           twister                NaN
# 6534   9345          survived         Texas, USA
# 6292   8989             storm                NaN
# 3163   4541         emergency  Renfrew, Scotland
# 6778   9710           tragedy                NaN
# ...     ...               ...                ...
# 6407   9159  suicide%20bomber          Worldwide
# 6393   9137    suicide%20bomb          Worldwide
# 6411   9166  suicide%20bomber                NaN
# 6414   9172  suicide%20bomber                NaN
# 7472  10689             wreck                NaN
#
#                                                    text  target  \
# 6992  Check out 'Want Twister Tickets AND A VIP EXPE...       0
# 6534  @thoutaylorbrown I feel like accidents are jus...       0
# 6292  TodayÛªs storm will pass; let tomorrowÛªs li...       1
# 3163  @batfanuk we enjoyed the show today. Great fun...       0
# 6778  Maaaaan I love Love Without Tragedy by @rihann...       0
# ...                                                 ...     ...
# 6407  17 killed in SÛªArabia mosque suicide bombing...       1
# 6393  ? 19th Day Since 17-Jul-2015 -- Nigeria: Suici...       1
# 6411  Suicide bomber kills 15 in Saudi security site...       1
# 6414  @Abu_Baraa1 Suicide bomber targets Saudi mosqu...       1
# 7472  wreck? wreck wreck wreck wreck wreck wreck wre...       0
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound  \
# 6992          0.000          0.402          0.598              0.9730
# 6534          0.049          0.412          0.539              0.9564
# 6292          0.000          0.509          0.491              0.9471
# 3163          0.084          0.354          0.563              0.9423
# 6778          0.000          0.381          0.619              0.9394
# ...             ...            ...            ...                 ...
# 6407          0.579          0.421          0.000             -0.9552
# 6393          0.583          0.417          0.000             -0.9595
# 6411          0.536          0.400          0.064             -0.9623
# 6414          0.542          0.458          0.000             -0.9686
# 7472          1.000          0.000          0.000             -0.9883
#
#      sentiment
# 6992  positive
# 6534  positive
# 6292  positive
# 3163  positive
# 6778  positive
# ...        ...
# 6407  negative
# 6393  negative
# 6411  negative
# 6414  negative
# 7472  negative
#
# [7503 rows x 10 columns]
# --- 0.13103246688842773 seconds ---

# %%
# export train data with sentiment analysis above
train_df.to_csv('sentiment_train_data.csv', index=False)

# %%
train_df['sentiment'].value_counts()
print('\n')
train_df['sentiment'].value_counts()/len(train_df)

positive_num = (train_df['sentiment'].value_counts())[2]
neutral_num = (train_df['sentiment'].value_counts())[1]
negative_num = (train_df['sentiment'].value_counts())[0]

positive = (train_df['sentiment'].value_counts()/len(train_df))[2]
neutral = (train_df['sentiment'].value_counts()/len(train_df))[1]
negative = (train_df['sentiment'].value_counts()/len(train_df))[0]

print(f'\n\nPositive Tweets: {round(positive*100,2)} % | \
Neutral Tweets: {round(neutral*100,2)} % | \
Negative Tweets: {round(negative*100,2)} %')
# Out:
# negative    3648
# neutral     1986
# positive    1869
# Name: sentiment, dtype: int64
# negative    0.486206
# neutral     0.264694
# positive    0.249100
# Name: sentiment, dtype: float64
# Positive Tweets: 24.91 % | Neutral Tweets: 26.47 % | Negative Tweets: 48.62 %

# %%
# Plot Bar Plot of Sentiment

# start time to measure the time of the program execution
start_time = time.time()

plt.figure(figsize=(10,10))
fig, ax = plt.subplots()

# creating the dataset
data = {'Positive': round(positive*100, 2), 'Neutral': round(neutral*100, 2),
        'Negative': round(negative*100, 2)}
classes = list(data.keys())
values = list(data.values())

cmap_red = plt.cm.get_cmap('Reds')
red = cmap_red(0.5)

cmap_gray = plt.cm.get_cmap('gray')
gray = cmap_gray(0.6)

cmap_org = plt.cm.get_cmap('GnBu')
blue = cmap_org(0.8)

p1 = ax.bar(classes, values, color=[red, gray, blue])
ax.set_ylabel('%')
ax.set_title('Sentiments in Disaster Tweets')
ax.set_xticks(classes)

# Label with label_type 'center' instead of the default 'edge'
ax.bar_label(p1)

plt.show()

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# Text(0, 0.5, '%')
# Text(0.5, 1.0, 'Sentiments in Disaster Tweets')
# [<matplotlib.axis.XTick at 0x25315267d60>,
#  <matplotlib.axis.XTick at 0x25315267d30>,
#  <matplotlib.axis.XTick at 0x253151b16d0>]
# [Text(0, 0, '24.91'), Text(0, 0, '26.47'), Text(0, 0, '48.62')]
# --- 1.1404187679290771 seconds ---

# %%
# Plot Bar Plot of Sentiment

# start time to measure the time of the program execution
start_time = time.time()

plt.figure(figsize=(10,10))
fig, ax = plt.subplots()

# creating the dataset
data = {'Positive': positive_num, 'Neutral': neutral_num,
        'Negative': negative_num}
classes = list(data.keys())
values = list(data.values())

cmap_red = plt.cm.get_cmap('Reds')
red = cmap_red(0.5)

cmap_gray = plt.cm.get_cmap('gray')
gray = cmap_gray(0.6)

cmap_org = plt.cm.get_cmap('GnBu')
blue = cmap_org(0.8)

p1 = ax.bar(classes, values, color=[red, gray, blue])
ax.set_ylabel('Number of Tweets')
ax.set_title('Sentiments in Disaster Tweets')
ax.set_xticks(classes)

# Label with label_type 'center' instead of the default 'edge'
ax.bar_label(p1)

plt.show()

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# Text(0, 0.5, 'Number of Tweets')
# Text(0.5, 1.0, 'Sentiments in Disaster Tweets')
# [<matplotlib.axis.XTick at 0x25315137820>,
#  <matplotlib.axis.XTick at 0x253151377f0>,
#  <matplotlib.axis.XTick at 0x253150f9370>]
# [Text(0, 0, '1869'), Text(0, 0, '1986'), Text(0, 0, '3648')]
# --- 0.27565908432006836 seconds ---

# %%
train_df['count'] = 1
train_df.info()
train_df.head(3)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 7503 entries, 6992 to 7472
# Data columns (total 11 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   id                  7503 non-null   int64
#  1   keyword             7447 non-null   object
#  2   location            5021 non-null   object
#  3   text                7503 non-null   object
#  4   target              7503 non-null   int64
#  5   sentiment_neg       7503 non-null   float64
#  6   sentiment_neu       7503 non-null   float64
#  7   sentiment_pos       7503 non-null   float64
#  8   sentiment_compound  7503 non-null   float64
#  9   sentiment           7503 non-null   object
#  10  count               7503 non-null   int64
# dtypes: float64(4), int64(3), object(4)
# memory usage: 703.4+ KB
#          id   keyword    location  \
# 6992  10028   twister         NaN
# 6534   9345  survived  Texas, USA
# 6292   8989     storm         NaN
#
#                                                    text  target  \
# 6992  Check out 'Want Twister Tickets AND A VIP EXPE...       0
# 6534  @thoutaylorbrown I feel like accidents are jus...       0
# 6292  TodayÛªs storm will pass; let tomorrowÛªs li...       1
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound  \
# 6992          0.000          0.402          0.598              0.9730
# 6534          0.049          0.412          0.539              0.9564
# 6292          0.000          0.509          0.491              0.9471
#
#      sentiment  count
# 6992  positive      1
# 6534  positive      1
# 6292  positive      1

# %%
# start time to measure the time of the program execution
start_time = time.time()

summary_pivot = pd.pivot_table(train_df, values=['count', 'sentiment_compound'],
                               index=['target', 'sentiment'],
                               aggfunc={'count': np.sum,
                                        'sentiment_compound': np.mean})
summary_pivot = summary_pivot.reset_index()
summary_pivot

train_df = train_df.drop(['count'], axis=1)
train_df.head(3)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
#    target sentiment  count  sentiment_compound
# 0       0  negative   1828           -0.499310
# 1       0   neutral   1124            0.000126
# 2       0  positive   1353            0.482879
# 3       1  negative   1820           -0.581670
# 4       1   neutral    862           -0.000228
# 5       1  positive    516            0.412525
#          id   keyword    location  \
# 6992  10028   twister         NaN
# 6534   9345  survived  Texas, USA
# 6292   8989     storm         NaN
#
#                                                    text  target  \
# 6992  Check out 'Want Twister Tickets AND A VIP EXPE...       0
# 6534  @thoutaylorbrown I feel like accidents are jus...       0
# 6292  TodayÛªs storm will pass; let tomorrowÛªs li...       1
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound  \
# 6992          0.000          0.402          0.598              0.9730
# 6534          0.049          0.412          0.539              0.9564
# 6292          0.000          0.509          0.491              0.9471
#
#      sentiment
# 6992  positive
# 6534  positive
# 6292  positive
# --- 0.07299637794494629 seconds ---

# %%
# Plot Bar Plot of Sentiment

# start time to measure the time of the program execution
start_time = time.time()

plt.figure(figsize=(10,8))

ax = sns.barplot(x='sentiment', y='count', hue='target', 
                 data=summary_pivot)
for container in ax.containers:
    ax.bar_label(container)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# [Text(0, 0, '1828'), Text(0, 0, '1124'), Text(0, 0, '1353')]
# [Text(0, 0, '1820'), Text(0, 0, '862'), Text(0, 0, '516')]
# --- 0.11949300765991211 seconds ---

# %%
# Plot Bar Plot of Sentiment

# start time to measure the time of the program execution
start_time = time.time()

plt.figure(figsize=(10,8))

ax = sns.barplot(x='sentiment', y='sentiment_compound', hue='target', 
                 data=summary_pivot)
for container in ax.containers:
    ax.bar_label(container)

# print the overall program runtime.
print(f"\n\n--- {(time.time() - start_time)} seconds ---")
# Out:
# [Text(0, 0, '-0.49931'), Text(0, 0, '0.000125979'), Text(0, 0, '0.482879')]
# [Text(0, 0, '-0.58167'), Text(0, 0, '-0.000228074'), Text(0, 0, '0.412525')]
# --- 0.053924560546875 seconds ---

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt
# %matplotlib inline

#sns.set_theme(style="ticks")
#sns.despine(fig)

#plt.figure(figsize = (17,13))
g = sns.FacetGrid(train_df, col="target", hue="sentiment", 
                  palette="mako", size=8)
g.map(sns.histplot, "sentiment_compound")
g.add_legend()

#g.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
g.set(ylim=(0, 1200))
#g.set_xticks([-1, -0.80, -0.6, -0.4, -0.2, 0,
#               0.2, 0.4, 0.6, 0.8, 1])

#plt.title('Sentiment for Twitter')
plt.show()
# Out:
# C:\Users\User\anaconda3\envs\jupyterlab-3.2.1\lib\site-packages\seaborn\axisgrid.py:337: UserWarning: The `size` parameter has been renamed to `height`; please update your code.
#   warnings.warn(msg, UserWarning)

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(8, 6))
sns.despine(f)

train_disaster = train_df[train_df['target']==1]

sns.histplot(
    train_disaster,
    x="sentiment_compound", 
    hue="sentiment",
    #multiple="stack",
    palette="mako",
    edgecolor=".5",
    linewidth=.7,
    #log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set(ylim=(0, 1200))
ax.set_xticks([-1, -0.80, -0.6, -0.4, -0.2, 0,
               0.2, 0.4, 0.6, 0.8, 1])
# Out:
# <AxesSubplot:xlabel='sentiment_compound', ylabel='Count'>
# [(0.0, 1200.0)]
# [<matplotlib.axis.XTick at 0x2531d120910>,
#  <matplotlib.axis.XTick at 0x2531d1208e0>,
#  <matplotlib.axis.XTick at 0x2531d15cdc0>,
#  <matplotlib.axis.XTick at 0x2531d1f2c70>,
#  <matplotlib.axis.XTick at 0x2531d1f2dc0>,
#  <matplotlib.axis.XTick at 0x2531d2007c0>,
#  <matplotlib.axis.XTick at 0x2531d206070>,
#  <matplotlib.axis.XTick at 0x2531d2066a0>,
#  <matplotlib.axis.XTick at 0x2531d206df0>,
#  <matplotlib.axis.XTick at 0x2531d20d580>,
#  <matplotlib.axis.XTick at 0x2531d206e50>]

# %%
import seaborn as sns
import matplotlib as mpl
import matplotlib.pyplot as plt

sns.set_theme(style="ticks")

f, ax = plt.subplots(figsize=(8, 6))
sns.despine(f)

train_nondisaster = train_df[train_df['target']==0]

sns.histplot(
    train_nondisaster,
    x="sentiment_compound", 
    hue="sentiment",
    #multiple="stack",
    palette="mako",
    edgecolor=".5",
    linewidth=.7,
    #log_scale=True,
)
ax.xaxis.set_major_formatter(mpl.ticker.ScalarFormatter())
ax.set(ylim=(0, 1200))
ax.set_xticks([-1, -0.80, -0.6, -0.4, -0.2, 0,
               0.2, 0.4, 0.6, 0.8, 1])
# Out:
# <AxesSubplot:xlabel='sentiment_compound', ylabel='Count'>
# [(0.0, 1200.0)]
# [<matplotlib.axis.XTick at 0x25318f5e6d0>,
#  <matplotlib.axis.XTick at 0x25318f5e6a0>,
#  <matplotlib.axis.XTick at 0x25318f84fd0>,
#  <matplotlib.axis.XTick at 0x25319018580>,
#  <matplotlib.axis.XTick at 0x25319018a60>,
#  <matplotlib.axis.XTick at 0x253190251f0>,
#  <matplotlib.axis.XTick at 0x25319025940>,
#  <matplotlib.axis.XTick at 0x2531902b0d0>,
#  <matplotlib.axis.XTick at 0x2531902b820>,
#  <matplotlib.axis.XTick at 0x25319032040>,
#  <matplotlib.axis.XTick at 0x2531902bbb0>]

# %%
negative_df = train_disaster[train_disaster['sentiment'] == 'negative']
negative_df = negative_df.sort_values(['sentiment_compound'])
negative_df
negative_sub_df = negative_df[['text', 'sentiment_compound']]
negative_sub_df
# Out:
#         id           keyword                     location  \
# 6414  9172  suicide%20bomber                          NaN
# 6411  9166  suicide%20bomber                          NaN
# 6393  9137    suicide%20bomb                    Worldwide
# 6407  9159  suicide%20bomber                    Worldwide
# 472    682            attack             portland, oregon
# ...    ...               ...                          ...
# 2185  3132            debris  Dubai, United Arab Emirates
# 2861  4112           drought                    Caribbean
# 3286  4712          evacuate                          NaN
# 3349  4794         evacuated                          NaN
# 2188  3136            debris              Berlin, Germany
#
#                                                    text  target  \
# 6414  @Abu_Baraa1 Suicide bomber targets Saudi mosqu...       1
# 6411  Suicide bomber kills 15 in Saudi security site...       1
# 6393  ? 19th Day Since 17-Jul-2015 -- Nigeria: Suici...       1
# 6407  17 killed in SÛªArabia mosque suicide bombing...       1
# 472   illegal alien released by Obama/DHS 4 times Ch...       1
# ...                                                 ...     ...
# 2185  What Irony Debris of Flight MH370 found on 'Re...       1
# 2861  Heat wave is relentless:  91å¡F Feels Like 100...       1
# 3286  CHICAGO (AP) ÛÓ Organizers of Lollapalooza sa...       1
# 3349  @115Film Doctor we must leave immediately the ...       1
# 2188  Experts leave lab as Malaysia confirms debris ...       1
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound  \
# 6414          0.542          0.458          0.000             -0.9686
# 6411          0.536          0.400          0.064             -0.9623
# 6393          0.583          0.417          0.000             -0.9595
# 6407          0.579          0.421          0.000             -0.9552
# 472           0.536          0.464          0.000             -0.9538
# ...             ...            ...            ...                 ...
# 2185          0.118          0.882          0.000             -0.0516
# 2861          0.124          0.680          0.196             -0.0516
# 3286          0.128          0.752          0.120             -0.0516
# 3349          0.054          0.946          0.000             -0.0516
# 2188          0.107          0.893          0.000             -0.0516
#
#      sentiment
# 6414  negative
# 6411  negative
# 6393  negative
# 6407  negative
# 472   negative
# ...        ...
# 2185  negative
# 2861  negative
# 3286  negative
# 3349  negative
# 2188  negative
#
# [1820 rows x 10 columns]
#                                                    text  sentiment_compound
# 6414  @Abu_Baraa1 Suicide bomber targets Saudi mosqu...             -0.9686
# 6411  Suicide bomber kills 15 in Saudi security site...             -0.9623
# 6393  ? 19th Day Since 17-Jul-2015 -- Nigeria: Suici...             -0.9595
# 6407  17 killed in SÛªArabia mosque suicide bombing...             -0.9552
# 472   illegal alien released by Obama/DHS 4 times Ch...             -0.9538
# ...                                                 ...                 ...
# 2185  What Irony Debris of Flight MH370 found on 'Re...             -0.0516
# 2861  Heat wave is relentless:  91å¡F Feels Like 100...             -0.0516
# 3286  CHICAGO (AP) ÛÓ Organizers of Lollapalooza sa...             -0.0516
# 3349  @115Film Doctor we must leave immediately the ...             -0.0516
# 2188  Experts leave lab as Malaysia confirms debris ...             -0.0516
#
# [1820 rows x 2 columns]

# %%
negative_sub_df[:21]
# Out:
#                                                    text  sentiment_compound
# 6414  @Abu_Baraa1 Suicide bomber targets Saudi mosqu...             -0.9686
# 6411  Suicide bomber kills 15 in Saudi security site...             -0.9623
# 6393  ? 19th Day Since 17-Jul-2015 -- Nigeria: Suici...             -0.9595
# 6407  17 killed in SÛªArabia mosque suicide bombing...             -0.9552
# 472   illegal alien released by Obama/DHS 4 times Ch...             -0.9538
# 1540  Bomb Crash Loot Riot Emergency Pipe Bomb Nucle...             -0.9524
# 6818  Bomb head? Explosive decisions dat produced mo...             -0.9500
# 6930  @cspan #Prez. Mr. President you are the bigges...             -0.9493
# 2844  @peterjukes A crime that killed/displaced mill...             -0.9467
# 6457  Remembering Mordechai Yehuda Friedman 24 of Ra...             -0.9451
# 4561  Udhampur terror attack: Militants attack polic...             -0.9451
# 6438  Remembering Rebecca Roga 40 of the Philippines...             -0.9451
# 4547  Udhampur terror attack: Militants attack polic...             -0.9451
# 4556  Udhampur terror attack: Militants attack polic...             -0.9451
# 6458  Remembering Marlene Menahem 22 of Moshav Safsu...             -0.9451
# 6601  #Politics DemocracyÛªs hatred for hate: Û_ D...             -0.9442
# 4540  Photos: 17 people killed and over 25 injured i...             -0.9413
# 160   Horrible Accident Man Died In Wings Of ÛÏAirp...             -0.9406
# 3623  Understand that there are no fatalities as no ...             -0.9403
# 5286  A Mad Catastrophe : The Outbreak of World War ...             -0.9403
# 1733  16 dead in Russia bus accident: At least 16 pe...             -0.9393

# %%
negative_sub_df[1800:]
# Out:
#                                                    text  sentiment_compound
# 2147  Weyburn Police Warn Public after Fentanyl Deat...             -0.1027
# 3209  #Nursing alert: Emergency Department Psychiatr...             -0.1027
# 1710  Monsoon flooding - Monsoon rains have have hit...             -0.1027
# 4385  Medieval airplane hijacker hard shell: casting...             -0.1027
# 6281  'Calgarians stunned by storm insurance compani...             -0.1027
# 1417  News Wrap: UN warns female and child casualtie...             -0.1027
# 1788  Deliver Value: A Cash Source Crash Course http...             -0.0772
# 1728  2 Cars Collide 1 Crashes Into Building: Two ca...             -0.0772
# 2009  Does homeowners insurance cover water damage? ...             -0.0772
# 6440  Malik Saadthe best police officer produced by ...             -0.0772
# 2764  @Pam_Palmater i agree with @perrybellegarde to...             -0.0772
# 3196  Can't fix stupid. MT @CBCCalgary Don't drive t...             -0.0577
# 4656  Myanmar's president urged people to leave a lo...             -0.0516
# 3264  Car engulfed in flames backs up traffic at Par...             -0.0516
# 1255  Now on WSLS: fire burns multiple buildings in ...             -0.0516
# 2185  What Irony Debris of Flight MH370 found on 'Re...             -0.0516
# 2861  Heat wave is relentless:  91å¡F Feels Like 100...             -0.0516
# 3286  CHICAGO (AP) ÛÓ Organizers of Lollapalooza sa...             -0.0516
# 3349  @115Film Doctor we must leave immediately the ...             -0.0516
# 2188  Experts leave lab as Malaysia confirms debris ...             -0.0516

# %%
neutral_df = train_disaster[train_disaster['sentiment'] == 'neutral']
neutral_df = neutral_df.sort_values(['sentiment_compound'])
neutral_df
neutral_sub_df = neutral_df[['text', 'sentiment_compound']]
neutral_sub_df
# Out:
#         id              keyword                        location  \
# 356    513                 army                          Studio
# 5132  7319    nuclear%20reactor           Phoenix, Arizona, USA
# 2402  3459             derailed                  Washington, DC
# 5061  7213   natural%20disaster  Oneonta, NY/ Staten Island, NY
# 1381  1991         bush%20fires                   beacon hills
# ...    ...                  ...                             ...
# 6553  9376             survived                             NaN
# 1570  2267         cliff%20fall                             NaN
# 5095  7267   nuclear%20disaster                             NaN
# 1346  1945  burning%20buildings                     Seattle, WA
# 2180  3124               debris        Hamilton, Ontario Canada
#
#                                                    text  target  \
# 356   But if you build an army of 100 dogs and their...       1
# 5132  If I'm also not mistaken we're sitting right n...       1
# 2402  Happy no one was hurt when #wmata train derail...       1
# 5061  its only getting colder and colder and faster ...       1
# 1381  @dacherryontop13 ohh there are bush fires in S...       1
# ...                                                 ...     ...
# 6553  Only one man Tsutomi Yamaguchi is said to have...       1
# 1570  #FunnyNews #Business Watch the moment a cliff ...       1
# 5095  The people who tweet and care about #Japan #Fu...       1
# 1346  I will never support looting or the burning of...       1
# 2180  Malaysia seem more certain than France.\n\nPla...       1
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound  \
# 356           0.138          0.730          0.132             -0.0387
# 5132          0.089          0.828          0.083             -0.0382
# 2402          0.251          0.533          0.216             -0.0314
# 5061          0.157          0.651          0.192             -0.0258
# 1381          0.096          0.812          0.092             -0.0258
# ...             ...            ...            ...                 ...
# 6553          0.131          0.735          0.135              0.0258
# 1570          0.107          0.780          0.112              0.0258
# 5095          0.218          0.528          0.255              0.0299
# 1346          0.185          0.662          0.153              0.0312
# 2180          0.141          0.705          0.153              0.0498
#
#      sentiment
# 356    neutral
# 5132   neutral
# 2402   neutral
# 5061   neutral
# 1381   neutral
# ...        ...
# 6553   neutral
# 1570   neutral
# 5095   neutral
# 1346   neutral
# 2180   neutral
#
# [862 rows x 10 columns]
#                                                    text  sentiment_compound
# 356   But if you build an army of 100 dogs and their...             -0.0387
# 5132  If I'm also not mistaken we're sitting right n...             -0.0382
# 2402  Happy no one was hurt when #wmata train derail...             -0.0314
# 5061  its only getting colder and colder and faster ...             -0.0258
# 1381  @dacherryontop13 ohh there are bush fires in S...             -0.0258
# ...                                                 ...                 ...
# 6553  Only one man Tsutomi Yamaguchi is said to have...              0.0258
# 1570  #FunnyNews #Business Watch the moment a cliff ...              0.0258
# 5095  The people who tweet and care about #Japan #Fu...              0.0299
# 1346  I will never support looting or the burning of...              0.0312
# 2180  Malaysia seem more certain than France.\n\nPla...              0.0498
#
# [862 rows x 2 columns]

# %%
neutral_sub_df[:21]
# Out:
#                                                    text  sentiment_compound
# 356   But if you build an army of 100 dogs and their...             -0.0387
# 5132  If I'm also not mistaken we're sitting right n...             -0.0382
# 2402  Happy no one was hurt when #wmata train derail...             -0.0314
# 5061  its only getting colder and colder and faster ...             -0.0258
# 1381  @dacherryontop13 ohh there are bush fires in S...             -0.0258
# 5130  Nuclear #Solar Power #Japanese #Fukushima Reac...             -0.0258
# 1408  I'M LAUGHING IN THE FACE OF CASUALTIES AND SOR...             -0.0258
# 3373  So the IFAK is an 'individual first aid kit' t...             -0.0258
# 3796  Found this cool photo not mine 1952 Dodge Wayn...             -0.0258
# 3799  when a monster truck racer catches on fire at ...             -0.0258
# 6221                    I get to smoke my shit in peace             -0.0258
# 69    Accident center lane blocked in #SantaClara on...             -0.0258
# 65    @nxwestmidlands huge fire at Wholesale markets...             -0.0258
# 6471  Japan FUSO Class Battleship YAMASHIRO Naval Co...             -0.0258
# 6866  Esteemed journalist recalls tragic effects of ...             -0.0258
# 3187  ÛÏ@based_georgie: yo forreal we need to have ...             -0.0258
# 4021  BE CAREFUL anyone who lives west of Beaverton....             -0.0173
# 6247  Sassy city girl country hunk stranded in Smoky...              0.0000
# 6234  Sassy city girl country hunk stranded in Smoky...              0.0000
# 6236  New #photo Oak in a snowstorm http://t.co/HK9Y...              0.0000
# 4514  @VinusTrip Did you see #hurricane #guillermo w...              0.0000

# %%
neutral_sub_df[841:]
# Out:
#                                                    text  sentiment_compound
# 5112  #Nuclear policy of #Japan without responsibili...              0.0000
# 5108  573 deaths have been certified by the Governme...              0.0000
# 6030  [Report 5] 18:22:45 Ibaraki Prefecture offing ...              0.0000
# 6035  #Sismo DETECTADO #JapÌ_n [Report 3] 01:02:17 O...              0.0000
# 4907  Tell @BarackObama to rescind medals of 'honor'...              0.0000
# 6043  A subcontractor working for French seismic sur...              0.0000
# 6028  #Sismo DETECTADO #JapÌ_n [Report 1] 01:01:56 O...              0.0000
# 5731  VIDEO: 'We're picking up bodies from water': R...              0.0000
# 5898  Watch This Airport Get Swallowed Up By A Sands...              0.0000
# 5122  US Navy Sidelines 3 Newest Subs - http://t.co/...              0.0000
# 5118  Global Nuclear Reactor Construction Market gre...              0.0000
# 4898  Remember this was a massacre of civilians. #Hi...              0.0000
# 6460  why wasn't this warship sunk?      CNN: First ...              0.0245
# 563   A young German stormtrooper engaged in the Bat...              0.0258
# 1414  Civilian Casualties in Afghanistan Reach Recor...              0.0258
# 6563  ÛÏ@BBCWomansHour: Setsuko Thurlow survived th...              0.0258
# 6553  Only one man Tsutomi Yamaguchi is said to have...              0.0258
# 1570  #FunnyNews #Business Watch the moment a cliff ...              0.0258
# 5095  The people who tweet and care about #Japan #Fu...              0.0299
# 1346  I will never support looting or the burning of...              0.0312
# 2180  Malaysia seem more certain than France.\n\nPla...              0.0498

# %%
positive_df = train_disaster[train_disaster['sentiment'] == 'positive']
positive_df = positive_df.sort_values(['sentiment_compound'], ascending=False)
positive_df
positive_sub_df = positive_df[['text', 'sentiment_compound']]
positive_sub_df
# Out:
#         id         keyword           location  \
# 6292  8989           storm                NaN
# 2457  3525      derailment                 UK
# 3048  4375      earthquake                NaN
# 1567  2263    cliff%20fall                nyc
# 4058  5765  forest%20fires                NaN
# ...    ...             ...                ...
# 2195  3144          debris                NaN
# 5298  7568        outbreak  Stockholm, Sweden
# 446    646          attack         Dallas, TX
# 3381  4843      evacuation       Bend, Oregon
# 4129  5870       hailstorm   Iliff,Colorado
#
#                                                    text  target  \
# 6292  TodayÛªs storm will pass; let tomorrowÛªs li...       1
# 2457  @Raishimi33 :) well I think that sounds like a...       1
# 3048  'There was a small earthquake in LA but don't ...       1
# 1567  ok peace I hope I fall off a cliff along with ...       1
# 4058  PRAY! For EAST COAST FOREST FIRES! PRAY! That ...       1
# ...                                                 ...     ...
# 2195  Debris confirmed from MH370; relatives hope fo...       1
# 5298  @SenateMajLdr let's try to do our best to prev...       1
# 446   Stay vigilent. Civil liberties are under const...       1
# 3381  Evacuation order lifted for town of Roosevelt ...       1
# 4129  Severe hailstorm in progress over Northeast Lo...       1
#
#       sentiment_neg  sentiment_neu  sentiment_pos  sentiment_compound  \
# 6292          0.000          0.509          0.491              0.9471
# 2457          0.000          0.425          0.575              0.9356
# 3048          0.000          0.543          0.457              0.8992
# 1567          0.000          0.347          0.653              0.8834
# 4058          0.000          0.539          0.461              0.8825
# ...             ...            ...            ...                 ...
# 2195          0.145          0.699          0.156              0.0516
# 5298          0.135          0.691          0.174              0.0516
# 446           0.201          0.584          0.214              0.0516
# 3381          0.159          0.721          0.120              0.0516
# 4129          0.194          0.597          0.209              0.0516
#
#      sentiment
# 6292  positive
# 2457  positive
# 3048  positive
# 1567  positive
# 4058  positive
# ...        ...
# 2195  positive
# 5298  positive
# 446   positive
# 3381  positive
# 4129  positive
#
# [516 rows x 10 columns]
#                                                    text  sentiment_compound
# 6292  TodayÛªs storm will pass; let tomorrowÛªs li...              0.9471
# 2457  @Raishimi33 :) well I think that sounds like a...              0.9356
# 3048  'There was a small earthquake in LA but don't ...              0.8992
# 1567  ok peace I hope I fall off a cliff along with ...              0.8834
# 4058  PRAY! For EAST COAST FOREST FIRES! PRAY! That ...              0.8825
# ...                                                 ...                 ...
# 2195  Debris confirmed from MH370; relatives hope fo...              0.0516
# 5298  @SenateMajLdr let's try to do our best to prev...              0.0516
# 446   Stay vigilent. Civil liberties are under const...              0.0516
# 3381  Evacuation order lifted for town of Roosevelt ...              0.0516
# 4129  Severe hailstorm in progress over Northeast Lo...              0.0516
#
# [516 rows x 2 columns]

# %%
positive_sub_df[:21]
# Out:
#                                                    text  sentiment_compound
# 6292  TodayÛªs storm will pass; let tomorrowÛªs li...              0.9471
# 2457  @Raishimi33 :) well I think that sounds like a...              0.9356
# 3048  'There was a small earthquake in LA but don't ...              0.8992
# 1567  ok peace I hope I fall off a cliff along with ...              0.8834
# 4058  PRAY! For EAST COAST FOREST FIRES! PRAY! That ...              0.8825
# 6966  @author_mike Amen today is the Day of Salvatio...              0.8788
# 3967  So grateful for all the support flooding in fr...              0.8693
# 882   it wasnt a very big stab but it was a deep sta...              0.8691
# 5609  George Njenga the hero saved his burning frien...              0.8625
# 5601  George Njenga the hero saved his burning frien...              0.8625
# 4071  GREAT MICHIGAN TECHNIQUE CAMP\nB1G THANKS TO @...              0.8579
# 1394  Another movie theater attack..close to home th...              0.8570
# 3810  I'm grateful for our first responders - @MNPDN...              0.8530
# 4143  @leedsrouge Love what you picked! We're playin...              0.8488
# 3833  At the #999day Emergency Services display! Mee...              0.8378
# 625   CDC has a pretty cool list of all bioterrorism...              0.8316
# 317   #PBBan (Temporary:300) hyider_ghost2 @'aRmaged...              0.8231
# 4435  @EvaHanderek @MarleyKnysh great times until th...              0.8225
# 6709  NIggas playing in the thunderstorm.. 'HOPE THE...              0.8189
# 1241  Such beautiful architecture in #NYC I love tho...              0.8126
# 4661  @LEDofficial1 As you can imagine we're inundat...              0.8126

# %%
positive_sub_df[495:]
# Out:
#                                                    text  sentiment_compound
# 4125  This was Boston yesterday after an intense hai...              0.0772
# 4044  A little concerned about the number of forest ...              0.0772
# 7224  Friendly reminder that the only country to eve...              0.0772
# 2162  @MayorofLondon pls reduce cyclist deaths with ...              0.0772
# 2816  #Myanmar  Displaced #Rohingya at #Sittwe point...              0.0772
# 6997  Crazy Mom Threw Teen Daughter a NUDE Twister S...              0.0772
# 5355  Truly a scene of chaos unprecedented in frenzy...              0.0772
# 1892  A diamond is just a piece of charcoal that han...              0.0763
# 7380  My precious olive tree lost this battle...anot...              0.0752
# 1760  Well Saturn doesn't exist anymore. So the coll...              0.0571
# 2176  [Reuters] Debris confirmed from MH370; relativ...              0.0516
# 1485  Chances are many of us are still digging out f...              0.0516
# 5052  @Cali74142290 lol natural disaster/hospital cr...              0.0516
# 1367  Insane bush fires in California. Be safe. http...              0.0516
# 2192  Debris confirmed from MH370; relatives hope fo...              0.0516
# 2190  #KAMINDOZ #reuters Debris confirmed from MH370...              0.0516
# 2195  Debris confirmed from MH370; relatives hope fo...              0.0516
# 5298  @SenateMajLdr let's try to do our best to prev...              0.0516
# 446   Stay vigilent. Civil liberties are under const...              0.0516
# 3381  Evacuation order lifted for town of Roosevelt ...              0.0516
# 4129  Severe hailstorm in progress over Northeast Lo...              0.0516
